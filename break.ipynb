# %%
import random
import csv

def initiate():
    
    #Initial variables & assignments
    
    global lives            #player lives
    global guesses          #list that gets filled with correct guesses
    global letters          #list of letters of guessword (in order)
    global guessword        #randomly generated guessword
    global oldguesses       #list of all old guesses (correct & incorrect)
    global length           #input number for length of guessword
    global grammar          #lives vs. life
    global filepath         #enter name (default)
    
    ###filepath ='/Users/thayneforbes/Desktop/words.csv'
    words = []
    oldguesses = []
    grammar = 'lives'
    
    print('Welcome to Hangman (in Afrikaans)! \n How many letters (4-12) do you want in the guess word?', end =' ')

    #Decide length of word & pick random word from list (either randomword or supplied list)
    while True:
        try:
            length = int(input())
            ###with open(filepath, newline='') as inputfile:
            ###    for row in csv.reader(inputfile):
            ###        words.append(row[0])
            words = ['hulle', 'hierdie', 'woord', 'sommige', 'ander', 'elke', 'vertel', 'doen', 'drie', 'goed', 'speel', 'klein', 'huis', 'lees', 'hand', 'hawe', 'groot', 'spel', 'selfs', 'land', 'hier', 'moet', 'sodanige', 'volg', 'verandering', 'gegaan', 'soort', 'nodig', 'huis', 'prentjie', 'weer', 'dier', 'punt', 'naby', 'self', 'aarde', 'vader', 'werk', 'deel', 'neem', 'plek', 'gemaak', 'lewe', 'waar', 'terug', 'bietjie', 'slegs', 'ronde', 'jaar', 'gekom', 'show', 'elke', 'goeie', 'onder', 'naam', 'baie', 'deur', 'vorm', 'vonnis', 'groot', 'dink', 'help', 'verskil', 'beurt', 'oorsaak', 'veel', 'beteken', 'voor', 'skuif', 'dieselfde', 'daar', 'wanneer', 'baie', 'hulle', 'skryf', 'soos', 'hierdie', 'lang', 'maak', 'ding', 'meer', 'aantal', 'klink', 'mees', 'mense', 'weet', 'water', 'oproep', 'eerste', 'kant', 'gewees', 'vind', 'hoof', 'staan', 'bladsy', 'behoort', 'land', 'gevind', 'antwoord', 'skool', 'groei', 'studie', 'steeds', 'leer', 'plant', 'dekking', 'voedsel', 'vier', 'tussen', 'staat', 'nooit', 'laaste', 'gedink', 'stad', 'boom', 'steek', 'plaas', 'hard', 'begin', 'storie', 'trek', 'verlaat', 'laat', 'terwyl', 'pers', 'naby', 'werklike', 'lewe', 'noord', 'boek', 'voer', 'wetenskap', 'kamer', 'vriend', 'begin', 'idee', 'berg', 'stop', 'keer', 'basis', 'hoor', 'perd', 'seker', 'kleur', 'gesig', 'hout', 'hoof', 'saam', 'volgende', 'kinders', 'begin', 'loop', 'byvoorbeeld', 'verlig', 'papier', 'groep', 'altyd', 'musiek', 'diegene', 'beide', 'merk', 'dikwels', 'brief', 'totdat', 'rivier', 'voete', 'sorg', 'tweede', 'genoeg', 'vlakte', 'meisie', 'gewone', 'jong', 'gereed', 'ooit', 'alhoewel', 'voel', 'bespreking', 'liggaam', 'gesin', 'direkte', 'inhou', 'verlaat', 'lied', 'meet', 'deur', 'produk', 'swart', 'kort', 'syfer', 'klas', 'wind', 'vraag', 'gebeur', 'volledige', 'skip', 'gebied', 'helfte', 'rock', 'orde', 'vuur', 'suid', 'probleem', 'stukkie', 'vertel', 'geweet', 'slaag', 'sedert', 'geheel', 'koning', 'straat', 'duim',
intig', 'glimlag', 'toename', 'spring', 'baba', 'dorpie', 'ontmoet', 'wortel', 'verhoog', 'metaal', 'stoot', 'sewe', 'paragraaf', 'derde', 'gehou', 'hare', 'beskryf', 'vloer', 'gevolg', 'brand', 'hill', 'veilig', 'oorweeg', 'tipe', 'afskrif', 'frase', 'stil', 'sand', 'grond', 'roll', 'temperatuur', 'vinger', 'bedryf', 'waarde', 'stryd', 'klop', 'opgewonde', 'natuurlike', 'view', 'kapitaal', 'stoel', 'gevaar', 'vrugte', 'soldaat', 'proses', 'bedryf', 'praktyk', 'afsonderlike', 'moeilik', 'dokter', 'asseblief', 'beskerm', 'middag', 'moderne', 'element', 'student', 'hoek', 'partytjie', 'toevoer', 'spoor', 'ring', 'karakter', 'insekte', 'gevang', 'tydperk', 'radio', 'gepraat', 'atoom', 'menslike', 'geskiedenis', 'uitwerking', 'elektriese', 'verwag', 'been', 'spoor', 'dink', 'verskaf', 'saamstem', 'sagte', 'vrou', 'kaptein', 'raai', 'nodige', 'skerp', 'vleuel', 'skep', 'naaste', 'wash', 'eerder', 'skare', 'koring', 'vergelyk', 'gedig', 'string', 'klok', 'afhang', 'vleis', 'buis', 'bekende', 'dollar', 'stroom', 'vrees', 'driehoek', 'planeet', 'haastig', 'hoof', 'kolonie', 'klok', 'betree', 'groot', 'vars', 'soek', 'stuur', 'geel', 'toelaat', 'druk', 'dood', 'spot', 'woestyn', 'huidige', 'lift', 'gestyg', 'meester', 'spoor', 'ouer', 'strand', 'afdeling', 'blad', 'stof', 'guns', 'koppel', 'post', 'spandeer', 'koord', 'oorspronklike', 'aandeel', 'stasie', 'brood', 'behoorlike', 'aanbod', 'segment', 'slaaf', 'eend', 'direkte', 'mark', 'graad', 'chick', 'liewe', 'vyand', 'antwoord', 'drink', 'voorkom', 'ondersteuning', 'toespraak', 'aard', 'reeks', 'stoom', 'beweging', 'vloeistof', 'bedoel', 'tande', 'suurstof', 'suiker', 'dood', 'mooi', 'vaardigheid', 'vroue', 'seisoen', 'oplossing', 'magnet', 'silwer', 'dankie', 'wedstryd', 'agtervoegsel', 'veral', 'bang', 'groot', 'suster', 'staal', 'bespreek', 'vorentoe', 'soortgelyke', 'ervaring', 'telling', 'appel', 'gekoop', 'steek', 'massa', 'kaart', 'groep', 'strokie', 'droom', 'aand', 'toestand', 'voer', 'hulpmiddel', 'totale', 'basiese', 'reuk', 'vallei', 'dubbel', 'sitplek', 'voortgaan', 'blok', 'grafiek', 'verkoop', 'sukses', 'maatskappy', 'aftrek', 'gebeurtenis', 'bepaalde', 'transaksie', 'swem', 'term', 'teenoorgestelde', 'vrou', 'skoen', 'skouer', 'verspreiding', 'kamp', 'bedink', 'katoen', 'gebore', 'bepaal', 'kwart', 'nege', 'vragmotor', 'geraas', 'vlak', 'kans', 'versamel', 'winkel', 'gooi', 'skyn', 'eiendom', 'kolom', 'molekule', 'kies', 'verkeerd', 'grys', 'herhaling', 'vereis', 'sout', 'neus', 'meervoud', 'woede', 'vasteland']
            filtered_words=[words[n] for n in range(0,len(words)-1) if len(words[n]) == int(length)]
            guessword=filtered_words[random.randint(0,len(filtered_words)-1)]
            #print(guessword)
            break
        except:
            print('Try between 4-12')
            continue

    #Decide number of lives            
    print(' How many lives do you want?', end=' ')
    while True:
        try:
            lives = int(input())
            break
        except ValueError:
            print('Enter a number')
            continue
    if lives == 1:
        grammar = 'life'

    #Turn word in to list of letters and empty guess word
    letters = list(guessword)
    guesses = ['_']*len(letters)

    #Initial print prompt with # lives & current word + length of word
    print('\n' + '_________________________________________________________________')
    print('You have ' + str(lives) + ' ' + grammar + '.\n')
    for item in range(0,len(letters)):
        print(guesses[item], sep=' ', end=' ', flush=True)
    print('\n')   

########################################################################################    
    
def move(lives, oldguesses):
    
    print('Guess a letter!')
    
    while True:
        
    #Input guess & append it to oldguesses list
        guess = input().lower()
        oldguesses.append(guess)
        
    #Check if the guess is in the guessword (works for multiple matches)
    #Puts the letter in the guesses list at the position(s) of the match
        if guess in letters:
            matches = [i for i, x in enumerate(letters) if x == guess]
            for x in matches:
                guesses[x] = guess
            
    #Win break
            if guesses == letters:
                print('\n' + 'You got it, well done!')
                print(guessword)
                playagain()
                break
            
    #Next move break
            else:
                print('_________________________________________________________________')
                print('Nice one.')
                reveal(guesses,lives)
                break
    #Bad guess break
        else:
            lives = lives - 1
            print('_________________________________________________________________')
            print('Bad guess.')
            reveal(guesses,lives)
            break

    while True:

    #End game break            
        if lives == 0:
            print('\n' + 'You lose! The word was: ' + guessword)
            playagain()
            break

    #Next move break
        else: 
            if guesses!=letters:
                move(lives, oldguesses)
                break
            else:
                break

########################################################################################    
            
def reveal(guesses,lives):
    
    #Reveals current state of the game, lives left & guesses so far            

    print("You've used these letters:", end=' ')
    for n in range(0,len(oldguesses)):
        print(oldguesses[n], sep=' ', end=', ', flush=True)
    grammar = 'lives'
    if lives == 1:
        grammar = 'life'
    print('and have ' + str(lives) + ' ' + grammar + ' left.')
    print('\n')
    for n in range(0,len(letters)):
        print(guesses[n], sep=' ', end=' ', flush=True)
    print('\n')

########################################################################################        
    
def playagain():

#Play again loop to call newgame() if players wants  

    print('Do you want to play again? (y/n)')
    while True:
        replay = input().upper()
        if replay == 'Y':
            newgame()
        elif replay == 'N':
            break

########################################################################################                

#New game function - calls initiate() to refresh word, then move()   
def newgame():
    initiate()
    move(lives, oldguesses) 
    
#Call new game
newgame()
# Out:
# Welcome to Hangman (in Afrikaans)!
#  How many letters (4-12) do you want in the guess word? 4
#  How many lives do you want? 3
#
# _________________________________________________________________
# You have 3 lives.
#
# _ _ _ _
#
# Guess a letter!
# 6
# _________________________________________________________________
# Bad guess.
# You've used these letters: 6, and have 2 lives left.
#
#
# _ _ _ _
#
# Guess a letter!
# a
# _________________________________________________________________
# Bad guess.
# You've used these letters: 6, a, and have 1 life left.
#
#
# _ _ _ _
#
# Guess a letter!
# e
# _________________________________________________________________
# Nice one.
# You've used these letters: 6, a, e, and have 1 life left.
#
#
# _ e _ _
#
# Guess a letter!
# n
# _________________________________________________________________
# Bad guess.
# You've used these letters: 6, a, e, n, and have 0 lives left.
#
#
# _ e _ _
#
#
# You lose! The word was: deur
# ...
